# %%
#1) Read Laliga.csv file replace dashes with 0

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('E:\python basics\Statistical learning Exam\Laliga.csv',na_values='-',skiprows=[0],sep=',')

# %%
df.fillna(0,inplace=True)
df
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86  4385.0       2762.0    1647.0
# 1     2            Barcelona       86  4262.0       2762.0    1581.0
# 2     3      Atletico Madrid       80  3442.0       2614.0    1241.0
# 3     4             Valencia       82  3386.0       2664.0    1187.0
# 4     5      Athletic Bilbao       86  3368.0       2762.0    1209.0
# 5     6              Sevilla       73  2819.0       2408.0     990.0
# 6     7             Espanyol       82  2792.0       2626.0     948.0
# 7     8        Real Sociedad       70  2573.0       2302.0     864.0
# 8     9             Zaragoza       58  2109.0       1986.0     698.0
# 9    10           Real Betis       51  1884.0       1728.0     606.0
# 10   11  Deportivo La Coruna       45  1814.0       1530.0     563.0
# 11   12           Celta Vigo       51  1789.0       1698.0     586.0
# 12   13           Valladolid       42  1471.0       1466.0     463.0
# ...

# %%
# 2) Print all the team stated playing between 1930 - 1980

# %%
split_debut = df.loc[:,'Debut'].str.split('-',expand=True).fillna(0).astype(int)
split_debut['Team'] = df['Team']
split_debut.columns=['debut','to','team']
split_debut.drop(['to'],axis=1,inplace=True)
split_debut[(split_debut.debut >= 1930) & (split_debut.debut <= 1980)]   
#sorted_team
# Out:
#     debut                 team
# 3    1931             Valencia
# 5    1934              Sevilla
# 8    1939             Zaragoza
# 9    1932           Real Betis
# 10   1941  Deportivo La Coruna
# 11   1939           Celta Vigo
# 12   1948           Valladolid
# 14   1944       Sporting Gijon
# 15   1935              Osasuna
# 16   1949               Malaga
# 17   1933               Oviedo
# 18   1960             Mallorca
# 19   1951           Las Palmas
# 21   1941              Granada
# 22   1977       Rayo Vallecano
# 23   1959                Elche
# 25   1935             Hercules
# 26   1961             Tenerife
# 27   1940               Murcia
# 28   1930               Alaves
# 29   1963              Levante
# 30   1974            Salamanca
# 31   1943             Sabadell
# 32   1977                Cadiz
# 34   1941            Castellon
# 37   1962              Cordoba
# 39   1978           Recreativo
# 40   1971            Burgos CF
# 41   1963           Pontevedra
# ...

# %%
# 3)Print the list of team top five Among points.

# %%
df.sort_values('Points',ascending = False).head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86  4385.0       2762.0    1647.0       552.0
# 1    2        Barcelona       86  4262.0       2762.0    1581.0       573.0
# 2    3  Atletico Madrid       80  3442.0       2614.0    1241.0       598.0
# 3    4         Valencia       82  3386.0       2664.0    1187.0       616.0
# 4    5  Athletic Bilbao       86  3368.0       2762.0    1209.0       633.0
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 0      563.0    5947.0        3140.0      33.0       23.0    8.0     8.0
# 1      608.0    5900.0        3114.0      25.0       25.0   12.0    12.0
# 2      775.0    4534.0        3309.0      10.0        8.0   16.0     9.0
# 3      861.0    4398.0        3469.0       6.0        6.0   10.0    11.0
# 4      920.0    4631.0        3700.0       8.0        7.0   10.0     5.0
#
#    Fifth  Sixth     T    Debut Since/LastApp  BestPosition
# ...

# %%
#4)
def Goal_diff_count(gf,ga):
    goal_diff = gf - ga.values
    return goal_diff
    
goal_diff = Goal_diff_count(df.iloc[:,8:9],df.iloc[:,9:10])

goal_diff['Goal Diffrence'] = goal_diff['GoalsFor']
goal_diff.drop(['GoalsFor'],axis=1,inplace=True)
max_count  = goal_diff.max()
min_count = goal_diff.min()
min_count =(-(min_count))
diff_max_min = Goal_diff_count(max_count,min_count)



print(diff_max_min)
goal_diff
# Out:
# Goal Diffrence    2282.0
# dtype: float64
#     Goal Diffrence
# 0           2807.0
# 1           2786.0
# 2           1225.0
# 3            929.0
# 4            931.0
# 5            307.0
# 6           -280.0
# 7             -2.0
# 8           -164.0
# 9           -333.0
# 10          -136.0
# 11          -346.0
# 12          -413.0
# 13          -525.0
# 14          -399.0
# 15          -334.0
# 16          -342.0
# 17          -309.0
# 18          -189.0
# 19          -399.0
# 20           103.0
# 21          -338.0
# 22          -328.0
# 23          -272.0
# 24          -113.0
# 25          -334.0
# 26          -125.0
# 27          -385.0
# 28          -165.0
# 29          -202.0
# ..             ...
# 31          -228.0
# 32          -269.0
# 33          -198.0
# 34          -169.0
# 35           -90.0
# 36          -122.0
# 37          -145.0
# 38           -42.0
# 39           -94.0
# 40           -94.0
# 41           -56.0
# 42           -98.0
# 43           -28.0
# ...

# %%
#5)
df['WinningPercentage'] = (df[['GamesWon']] / df[['GamesPlayed']].values)*100
df.fillna(0)
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86  4385.0       2762.0    1647.0
# 1     2            Barcelona       86  4262.0       2762.0    1581.0
# 2     3      Atletico Madrid       80  3442.0       2614.0    1241.0
# 3     4             Valencia       82  3386.0       2664.0    1187.0
# 4     5      Athletic Bilbao       86  3368.0       2762.0    1209.0
# 5     6              Sevilla       73  2819.0       2408.0     990.0
# 6     7             Espanyol       82  2792.0       2626.0     948.0
# 7     8        Real Sociedad       70  2573.0       2302.0     864.0
# 8     9             Zaragoza       58  2109.0       1986.0     698.0
# 9    10           Real Betis       51  1884.0       1728.0     606.0
# 10   11  Deportivo La Coruna       45  1814.0       1530.0     563.0
# 11   12           Celta Vigo       51  1789.0       1698.0     586.0
# 12   13           Valladolid       42  1471.0       1466.0     463.0
# ...

# %%
#Top Five team having higest Percentage.
top = df.sort_values('WinningPercentage',ascending = False).head(5)
team = top.loc[:,'Team']
team
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
#6) Group by best position and print the sum of their points for all positions.
df.groupby(['Pos','Points']).sum().head(2)
# Out:
#             Seasons  GamesPlayed  GamesWon  GamesDrawn  GamesLost  GoalsFor  \
# Pos Points
# 1   4385.0       86       2762.0    1647.0       552.0      563.0    5947.0
# 2   4262.0       86       2762.0    1581.0       573.0      608.0    5900.0
#
#             GoalsAgainst  Champion  Runner-up  Third  Fourth  Fifth  Sixth  \
# Pos Points
# 1   4385.0        3140.0      33.0       23.0    8.0     8.0    3.0    4.0
# 2   4262.0        3114.0      25.0       25.0   12.0    12.0    4.0    6.0
#
#                T  BestPosition
# Pos Points
# 1   4385.0  79.0             1
# 2   4262.0  83.0             1
